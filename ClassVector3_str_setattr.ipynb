# %%
import math

class vector3:
   '''this vector classs'''
   #constructor
   def __init__(self, name="default", xval=0.0, yval=0.0, zval=0.0):
       '''this is my constructor for my class'''
       self.name = name
       self.xval = xval
       self.yval = yval
       self.zval = zval
   def __str__(self):
       '''string override for vector class'''
       return "vector3p{}] = ({},{},{}) lengthe:()".format(self.name, self.xval, self.yval, self.zval, self.computeLength)
       
   def __setattr__(self,name,value): #shi setattr not setatter
       '''this my setattr override where I check the propper varibel name'''
       if name == "name" or name == "xval" or name == "yval" or name == "zval":
           self.__dict__[name] = value
       else:
           raise valueError, "setatter: invalid vector arrtribute name{}".format(name)
           
   def computeLength(self):
      '''compute the length of my vector 3 class and returen it as a float'''
      return math.sqrt(self.xval*self.xval + self.yval*self.yval + self.zval*self.zval)
   
   def __add__(self,other):
      '''add my vector withr another vectore and return a new vector'''
      newVectorName = "{}+{}".format(self.name, other)
      return vector3(newVectorName, self.xval+other.xval, self.yval+other.yval, self.zval+other.zval)
   
   def __sub__(self,other):
      '''add my vector withr another vectore and return a new vector'''
      newVectorName = "{}-{}".format(self.name, other)
      return vector3(newVectorName, self.xval-other.xval, self.yval-other.yval, self.zval-other.zval)   
      
   def __invert__(self):
      ''' compute the inversion of my verctor to reutrn it as a new vector'''
      newVectorName = "~{}".format(self.name)
      return vector3(newVectorName, -1*self.xval, -1*self.yval, -1*self.zval)
   
   def __mul__(self):
      '''pberrode tje p[eratpr wotje vectpre crpss[rpdict amd retirem result'''
      newVectorName = "{}*{}".format(self.name, other.name)
      return Vector3(newVectorName, (self.yval*other.zval))-(self.zval*other.yval),
      
           
fooo = vector3("sham",1.0, 2.0, 3.0)
print fooo
bar = ~fooo
print bar

groovy = fooo + bar
print groovy

#fooo.xval = 20
#print fooo
#print fooo.computeLength
